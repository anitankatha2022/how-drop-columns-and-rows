# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\USER\\Desktop\\CASI\\housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.drop(labels='furnishingstatus',axis=1)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df["mainroad"]=df["mainroad"].map({"yes":1,"no":0})
df['guestroom']=df['guestroom'].map({'yes':1,'no':0})
df['basement']=df['basement'].map({'yes':1,'no':0})
df['hotwaterheating']=df['hotwaterheating'].map({'yes':1,'no':0})
df['airconditiong']=df['airconditioning'].map({'yes':1,'no':0})
df['prefarea']=df['prefarea'].map({'yes':1,'no':0})

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating airconditioning  parking  prefarea  \
# 0         0                0             yes        2         1
# 1         0                0             yes        3         0
# 2         1                0              no        2         1
# 3         1                0             yes        3         1
# 4         1                0             yes        2         0
#
#   furnishingstatus  airconditiong
# 0        furnished              1
# 1        furnished              1
# 2   semi-furnished              0
# ...

# %%
df.drop(labels=[1,3])
# Out:
#      airconditiong airconditioning      area  basement  bathrooms  bedrooms  \
# 0         1.471267             NaN  1.045766 -0.733865   1.420507  1.402131
# 2        -0.678439             NaN  2.216196  1.360148   1.420507  0.047235
# 4         1.471267             NaN  1.045766  1.360148  -0.569663  1.402131
# 5         1.471267             NaN  1.082630  1.360148   3.410677  0.047235
# 6         1.471267             NaN  1.580293 -0.733865   3.410677  1.402131
# ..             ...             ...       ...       ...        ...       ...
# 540      -0.678439             NaN -0.990968  1.360148  -0.569663 -1.307661
# 541      -0.678439             NaN -1.267448 -0.733865  -0.569663  0.047235
# 542      -0.678439             NaN -0.705273 -0.733865  -0.569663 -1.307661
# 543      -0.678439             NaN -1.032440 -0.733865  -0.569663  0.047235
# 544      -0.678439             NaN -0.599289 -0.733865  -0.569663  0.047235
#
# ...

# %%
df.drop(index=[1,5])
# Out:
#      airconditiong airconditioning      area  basement  bathrooms  bedrooms  \
# 0         1.471267             NaN  1.045766 -0.733865   1.420507  1.402131
# 2        -0.678439             NaN  2.216196  1.360148   1.420507  0.047235
# 3         1.471267             NaN  1.082630  1.360148   1.420507  1.402131
# 4         1.471267             NaN  1.045766  1.360148  -0.569663  1.402131
# 6         1.471267             NaN  1.580293 -0.733865   3.410677  1.402131
# ..             ...             ...       ...       ...        ...       ...
# 540      -0.678439             NaN -0.990968  1.360148  -0.569663 -1.307661
# 541      -0.678439             NaN -1.267448 -0.733865  -0.569663  0.047235
# 542      -0.678439             NaN -0.705273 -0.733865  -0.569663 -1.307661
# 543      -0.678439             NaN -1.032440 -0.733865  -0.569663  0.047235
# 544      -0.678439             NaN -0.599289 -0.733865  -0.569663  0.047235
#
# ...

# %%
df.drop(columns=['area','basement'])
# Out:
#      airconditiong airconditioning  bathrooms  bedrooms furnishingstatus  \
# 0         1.471267             NaN   1.420507  1.402131              NaN
# 1         1.471267             NaN   5.400847  1.402131              NaN
# 2        -0.678439             NaN   1.420507  0.047235              NaN
# 3         1.471267             NaN   1.420507  1.402131              NaN
# 4         1.471267             NaN  -0.569663  1.402131              NaN
# ..             ...             ...        ...       ...              ...
# 540      -0.678439             NaN  -0.569663 -1.307661              NaN
# 541      -0.678439             NaN  -0.569663  0.047235              NaN
# 542      -0.678439             NaN  -0.569663 -1.307661              NaN
# 543      -0.678439             NaN  -0.569663  0.047235              NaN
# 544      -0.678439             NaN  -0.569663  0.047235              NaN
#
#      guestroom  hotwaterheating  mainroad   parking  prefarea     price  \
# ...

# %%
df.drop(index=[541,542],columns=['area','basement'])
# Out:
#      airconditiong airconditioning  bathrooms  bedrooms furnishingstatus  \
# 0         1.471267             NaN   1.420507  1.402131              NaN
# 1         1.471267             NaN   5.400847  1.402131              NaN
# 2        -0.678439             NaN   1.420507  0.047235              NaN
# 3         1.471267             NaN   1.420507  1.402131              NaN
# 4         1.471267             NaN  -0.569663  1.402131              NaN
# ..             ...             ...        ...       ...              ...
# 538      -0.678439             NaN  -0.569663 -1.307661              NaN
# 539      -0.678439             NaN  -0.569663 -1.307661              NaN
# 540      -0.678439             NaN  -0.569663 -1.307661              NaN
# 543      -0.678439             NaN  -0.569663  0.047235              NaN
# 544      -0.678439             NaN  -0.569663  0.047235              NaN
#
#      guestroom  hotwaterheating  mainroad   parking  prefarea     price  \
# ...

# %%
df.drop(index=[543,580],columns=['area'],errors='ignore')
# Out:
#      airconditiong airconditioning  basement  bathrooms  bedrooms  \
# 0         1.471267             NaN -0.733865   1.420507  1.402131
# 1         1.471267             NaN -0.733865   5.400847  1.402131
# 2        -0.678439             NaN  1.360148   1.420507  0.047235
# 3         1.471267             NaN  1.360148   1.420507  1.402131
# 4         1.471267             NaN  1.360148  -0.569663  1.402131
# ..             ...             ...       ...        ...       ...
# 539      -0.678439             NaN -0.733865  -0.569663 -1.307661
# 540      -0.678439             NaN  1.360148  -0.569663 -1.307661
# 541      -0.678439             NaN -0.733865  -0.569663  0.047235
# 542      -0.678439             NaN -0.733865  -0.569663 -1.307661
# 544      -0.678439             NaN -0.733865  -0.569663  0.047235
#
#     furnishingstatus  guestroom  hotwaterheating  mainroad   parking  \
# 0                NaN  -0.464888        -0.219063  0.405251  1.516299
# ...

# %%
df=(df-df.mean())/df.std()
df.head()
# Out:
#    airconditiong airconditioning      area  basement  bathrooms  bedrooms  \
# 0       1.471267             NaN  1.045766 -0.733865   1.420507  1.402131
# 1       1.471267             NaN  1.755397 -0.733865   5.400847  1.402131
# 2      -0.678439             NaN  2.216196  1.360148   1.420507  0.047235
# 3       1.471267             NaN  1.082630  1.360148   1.420507  1.402131
# 4       1.471267             NaN  1.045766  1.360148  -0.569663  1.402131
#
#   furnishingstatus  guestroom  hotwaterheating  mainroad   parking  prefarea  \
# 0              NaN  -0.464888        -0.219063  0.405251  1.516299  1.803284
# 1              NaN  -0.464888        -0.219063  0.405251  2.676950 -0.553526
# 2              NaN  -0.464888        -0.219063  0.405251  1.516299  1.803284
# 3              NaN  -0.464888        -0.219063  0.405251  2.676950  1.803284
# 4              NaN   2.147110        -0.219063  0.405251  1.516299 -0.553526
#
#       price   stories
# 0  4.562174  1.376952
# ...

# %%
x=df['furnished']
y=df['semi-furnished']
